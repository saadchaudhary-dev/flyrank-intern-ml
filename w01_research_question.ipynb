# %% [markdown]
# <a href="https://colab.research.google.com/github/saadchaudhary-dev/flyrank-intern-ml/blob/main/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/saadchaudhary-dev/flyrank-intern-ml/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
My Lane: Refresh / Content Opportunity Scoring

chose the Refresh / Content Opportunity Scoring lane because websites often contain pages that have lost traffic or rankings over time.
Updating every page is expensive and time-consuming, so it is important to identify which pages are most likely to benefit from a content refresh.
My goal is to build a decision-support approach that helps prioritize pages based on their observed performance metrics,
allowing content teams to focus their efforts where they are most likely to improve search visibility.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
Markdown Cell

Research Question

The decision this project supports is which existing pages should be refreshed first.

The primary users are SEO specialists and content managers who decide where to invest time updating content.

A correct recommendation helps improve organic visibility while reducing unnecessary work. A wrong recommendation could cause valuable
pages to be ignored or resources to be spent updating pages that are unlikely to improve. Therefore, the goal is to provide decision-support
rather than guarantee future ranking improvements.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("starter.csv")   # replace with your actual filename

print("Number of pages:", len(df))
print("Average impressions (90d):", round(df["impressions_90d"].mean(), 2))
print("Median search volume:", round(df["search_volume"].median(), 2))

Then, after running it, copy the actual numbers into the markdown.

Example (replace these numbers with yours):

Quick Look at the Data

The dataset contains 12,483 pages. The average number of impressions during the last 90 days is 1,842,
while the median keyword search volume is 170. These numbers suggest that page performance varies substantially,
making it worthwhile to investigate which pages may benefit most from a content refresh.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
Markdown Cell

Scope of This Work

This project will measure relationships between existing page metrics and develop a decision-support method for identifying pages that may have high refresh potential.
The results can help prioritize content updates based on observed data.

This project will not prove that refreshing a page will cause higher rankings or increased traffic.
It will not predict Google's ranking algorithm or guarantee future search performance.
Any recommendations should be interpreted as evidence-based guidance rather than certainty.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
