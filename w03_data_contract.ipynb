# %% [markdown]
# <a href="https://colab.research.google.com/github/saadchaudhary-dev/flyrank-intern-ml/blob/main/w03_data_contract.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/saadchaudhary-dev/flyrank-intern-ml/blob/main/work/notebooks/w03_data_contract.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
Each row in the dataset represents one webpage (URL) together with its observed SEO and search performance metrics.
Most performance metrics summarize activity over the last 90 days, such as impressions_90d and clicks_90d.
This means the analysis is performed at the page level using aggregated observations from a fixed time window rather than daily records.

Code Cell
import pandas as pd

df = pd.read_csv("starter.csv")   # Replace with your dataset filename

print("Rows:", len(df))
print("Columns:", len(df.columns))
print("\nSample data:")
print(df.head())

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
Data Contract
Features

These variables will be used to estimate refresh opportunity.

search_volume
impressions_90d
clicks_90d
ctr
position
page_age (if available)
backlinks (if available)
Label (Proxy)

There is no direct label indicating whether a page should be refreshed. Therefore, the project will use a proxy opportunity score derived from observed SEO metrics.

Context

These fields provide information but are not used directly for prediction.

url
page_title
category
publish_date
Excluded Fields
IDs or internal identifiers (not useful for prediction)
Duplicate columns
Fields with excessive missing values
Columns that directly reveal the target (to avoid data leakage)
Code Cell
print("Dataset Columns:\n")

for col in df.columns:
    print(col)

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
Data Contract Verification

The following checks verify the dataset:

One row represents one webpage.
The dataset size matches expectations.
Missing values are identified.
Duplicate records are checked.
The selected features are available.
Code Cell
# Dataset size
print("Number of rows:", len(df))
# Duplicate rows
print("Duplicate rows:", df.duplicated().sum())
# Missing values
print("\nMissing Values:")
print(df.isnull().sum())
# Data types
print("\nData Types:")
print(df.dtypes)

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
Data Limitations

This dataset provides observed SEO metrics but cannot explain why a page performs well or poorly.
It cannot prove that refreshing a page will increase rankings or traffic.

Additional limitations include:
Metrics are aggregated over a limited time period.
External factors such as Google algorithm updates, competitors, and seasonality are not fully captured.
Missing values may reduce the reliability of some analyses.
The project provides decision support, not guaranteed outcomes or causal conclusions.
Code Cell
print("Dataset Summary")

print(df.describe(include="all"))

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
