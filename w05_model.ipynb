# %% [markdown]
# <a href="https://colab.research.google.com/github/saadchaudhary-dev/flyrank-intern-ml/blob/main/w05_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-08 — Capstone Modeling Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/saadchaudhary-dev/flyrank-intern-ml/blob/main/work/notebooks/w05_model.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Method choice and why
#
# *Which method from the toolkit, and why it fits your lane.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
I chose Random Forest for this part of the project because it can pick up on non-linear patterns between features and works well with structured tabular SEO data.

Compared to the Week-4 baseline, Random Forest combines multiple decision trees together, which helps reduce overfitting and gives better predictions.
It also shows feature importance, so we can understand which signals are actually driving the predictions.

The point isn't to use a more complex model just for the sake of it, but to check whether it actually performs better than the baseline, using the same data, split, and evaluation metric.

# %% [markdown]
# ## 2. Split design
#
# *Grouped by client? Time-aware? Say why this split is honest for your question.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
I used the same train/test split as my Week-4 baseline to keep the comparison fair.

This way, any difference in performance comes from the model itself, not from different evaluation data.
The test set isn't used during training at all, which helps avoid data leakage.

# %% [markdown]
# ## 3. Train + compare vs my baseline
#
# *Same data, same metric, same split as your Week-4 baseline. Show the table.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
The model was trained on the same training data and tested on the same test data as the Week-4 baseline.

I used the same evaluation metric too, so the performance results can be compared directly.

# %% [markdown]
# ## 4. Errors and interpretation
#
# *Where is the model wrong? What does it lean on? A short error analysis beats a big metric table.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
The model does well on common patterns in the data but makes bigger errors on unusual or low-frequency examples.

Feature importance shows that only a few features are driving most of the predictions, while the rest have very little impact.

These findings are observations and give a general direction. They should be used to support decisions, not treated as definite proof of cause and effect.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
